# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy.interpolate import make_interp_spline, BSpline

#gaps are caused by other computer processes execution
plt.axis([0,10000000,0,4000])
plt.title('Qsort on central pivot')
plt.xlabel('size')
plt.ylabel('time, ms')

x = np.array([1000, 101000, 201000, 301000, 401000, 501000, 601000, 701000, 801000, 901000, 1001000, 1101000, 1201000, 1301000, 1401000, 1501000, 1601000, 1701000, 1801000, 1901000, 2001000, 2101000, 2201000, 2301000, 2401000, 2501000, 2601000, 2701000, 2801000, 2901000, 3001000, 3101000, 3201000, 3301000, 3401000, 3501000, 3601000, 3701000, 3801000, 3901000, 4001000, 4101000, 4201000, 4301000, 4401000, 4501000, 4601000, 4701000, 4801000, 4901000, 5001000, 5101000, 5201000, 5301000, 5401000, 5501000, 5601000, 5701000, 5801000, 5901000, 6001000, 6101000, 6201000, 6301000, 6401000, 6501000, 6601000, 6701000, 6801000, 6901000, 7001000, 7101000, 7201000, 7301000, 7401000, 7501000, 7601000, 7701000, 7801000, 7901000, 8001000, 8101000, 8201000, 8301000, 8401000, 8501000, 8601000, 8701000, 8801000, 8901000, 9001000, 9101000, 9201000, 9301000, 9401000, 9501000, 9601000, 9701000, 9801000, 9901000])
y = np.array([0,12,27,41,58,76,91,106,123,141,154,171,192,212,234,242,269,291,298,329,338,363,377,397,487,514,523,546,598,663,670,671,644,750,689,761,808,780,780,813,799,725,727,748,768,813,3294,2778,777,871,917,927,950,930,938,956,973,996,1014,1027,1059,1061,1086,1106,1134,1144,1168,1180,1196,1225,1239,1262,1267,1300,1321,1334,1354,1369,1397,1408,1436,1438,1470,1483,1498,1529,1538,1586,1577,1595,1603,1645,1668,1656,1692,1695,1725,1738,1771,1776])

xnew = np.linspace (x. min (), x. max (), 200 ) 

spl = make_interp_spline (x, y, k = 1)
y_smooth = spl (xnew)

plt.plot (xnew, y_smooth)
plt.show()

plt.axis([0,10000000,0,4000])
plt.title('Qsort on median of three pivot')
plt.xlabel('size')
plt.ylabel('time, ms')

x = np.array([1000, 101000, 201000, 301000, 401000, 501000, 601000, 701000, 801000, 901000, 1001000, 1101000, 1201000, 1301000, 1401000, 1501000, 1601000, 1701000, 1801000, 1901000, 2001000, 2101000, 2201000, 2301000, 2401000, 2501000, 2601000, 2701000, 2801000, 2901000, 3001000, 3101000, 3201000, 3301000, 3401000, 3501000, 3601000, 3701000, 3801000, 3901000, 4001000, 4101000, 4201000, 4301000, 4401000, 4501000, 4601000, 4701000, 4801000, 4901000, 5001000, 5101000, 5201000, 5301000, 5401000, 5501000, 5601000, 5701000, 5801000, 5901000, 6001000, 6101000, 6201000, 6301000, 6401000, 6501000, 6601000, 6701000, 6801000, 6901000, 7001000, 7101000, 7201000, 7301000, 7401000, 7501000, 7601000, 7701000, 7801000, 7901000, 8001000, 8101000, 8201000, 8301000, 8401000, 8501000, 8601000, 8701000, 8801000, 8901000, 9001000, 9101000, 9201000, 9301000, 9401000, 9501000, 9601000, 9701000, 9801000, 9901000])
y = np.array([0,12,26,40,58,77,90,105,122,138,155,170,191,206,229,244,260,285,293,316,336,362,367,397,449,506,524,541,577,649,658,689,637,687,709,737,833,753,774,793,793,751,736,736,750,789,2728,2933,1091,849,879,915,931,919,920,945,955,983,992,1020,1030,1053,1075,1087,1114,1121,1143,1153,1182,1195,1222,1237,1252,1279,1289,1318,1325,1349,1369,1377,1404,1422,1455,1450,1480,1498,1521,1551,1549,1563,1571,1613,1635,1642,1656,1665,1704,1712,1733,1739])

xnew = np.linspace (x. min (), x. max (), 200 ) 
spl = make_interp_spline (x, y, k = 1)
y_smooth = spl (xnew)

plt.plot (xnew, y_smooth)
plt.show()


plt.axis([0,10000000,0,13000])
plt.title('Qsort on median of medians pivot')
plt.xlabel('size')
plt.ylabel('time, ms')

x = np.array([1000, 101000, 201000, 301000, 401000, 501000, 601000, 701000, 801000, 901000, 1001000, 1101000, 1201000, 1301000, 1401000, 1501000, 1601000, 1701000, 1801000, 1901000, 2001000, 2101000, 2201000, 2301000, 2401000, 2501000, 2601000, 2701000, 2801000, 2901000, 3001000, 3101000, 3201000, 3301000, 3401000, 3501000, 3601000, 3701000, 3801000, 3901000, 4001000, 4101000, 4201000, 4301000, 4401000, 4501000, 4601000, 4701000, 4801000, 4901000, 5001000, 5101000, 5201000, 5301000, 5401000, 5501000, 5601000, 5701000, 5801000, 5901000, 6001000, 6101000, 6201000, 6301000, 6401000, 6501000, 6601000, 6701000, 6801000, 6901000, 7001000, 7101000, 7201000, 7301000, 7401000, 7501000, 7601000, 7701000, 7801000, 7901000, 8001000, 8101000, 8201000, 8301000, 8401000, 8501000, 8601000, 8701000, 8801000, 8901000, 9001000, 9101000, 9201000, 9301000, 9401000, 9501000, 9601000, 9701000, 9801000, 9901000])
y = np.array([0,45,99,159,222,300,349,408,477,542,601,672,745,808,929,981,1048,1150,1230,1258,1333,1405,1477,1522,1760,2039,2095,2106,2312,2587,2640,2709,2544,2731,2811,2948,3243,2943,3045,3213,3140,2893,2893,2974,2970,3132,11369,10987,4977,3397,3534,3616,3703,3633,3658,3762,3773,3913,3975,4043,4150,4200,4257,4396,4467,4470,4528,4610,4732,4814,4820,5016,4996,5104,5155,5288,5249,5479,5533,5523,5637,5650,5744,5795,5914,5995,6095,6248,6227,6323,6353,6614,6478,6532,6634,6619,6811,6807,6996,6990])

xnew = np.linspace (x. min (), x. max (), 200 ) 
spl = make_interp_spline (x, y, k = 1)
y_smooth = spl (xnew)

plt.plot (xnew, y_smooth)
plt.show()


plt.axis([0,10000000,0,30000])
plt.title('Qsort on random pivot')
plt.xlabel('size')
plt.ylabel('time, ms')

x = np.array([1000, 101000, 201000, 301000, 401000, 501000, 601000, 701000, 801000, 901000, 1001000, 1101000, 1201000, 1301000, 1401000, 1501000, 1601000, 1701000, 1801000, 1901000, 2001000, 2101000, 2201000, 2301000, 2401000, 2501000, 2601000, 2701000, 2801000, 2901000, 3001000, 3101000, 3201000, 3301000, 3401000, 3501000, 3601000, 3701000, 3801000, 3901000, 4001000, 4101000, 4201000, 4301000, 4401000, 4501000, 4601000, 4701000, 4801000, 4901000, 5001000, 5101000, 5201000, 5301000, 5401000, 5501000, 5601000, 5701000, 5801000, 5901000, 6001000, 6101000, 6201000, 6301000, 6401000, 6501000, 6601000, 6701000, 6801000, 6901000, 7001000, 7101000, 7201000, 7301000, 7401000, 7501000, 7601000, 7701000, 7801000, 7901000, 8001000, 8101000, 8201000, 8301000, 8401000, 8501000, 8601000, 8701000, 8801000, 8901000, 9001000, 9101000, 9201000, 9301000, 9401000, 9501000, 9601000, 9701000, 9801000, 9901000])
y = np.array ([1,120,248,365,515,669,784,907,1051,1179,1298,1431,1594,1738,1922,2004,2188,2328,2469,2600,2710,2879,3009,3093,3682,4045,4174,4294,4708,5204,5157,5401,5027,5527,5450,5872,6299,5889,5995,6300,6037,5643,5621,5731,5818,6179,25184,21342,6328,6560,7099,7074,7313,7055,7086,7286,7344,7537,7642,7776,7947,8002,8193,8285,8473,8554,8747,8844,8973,9147,9210,9425,9534,9720,9769,9973,10075,10204,10385,10438,10659,10690,10888,10980,11117,11293,11357,11695,11690,11801,11876,12078,12243,12279,12485,12506,12731,12773,12995,13082])

xnew = np.linspace (x. min (), x. max (), 200 ) 
spl = make_interp_spline (x, y, k = 1)
y_smooth = spl (xnew)

plt.plot (xnew, y_smooth)
plt.show()

plt.axis([0,410000,0,500000])
plt.title('bubble sort')
plt.xlabel('size')
plt.ylabel('time, ms')

x = np.array([1000, 11000, 21000, 31000, 41000, 51000, 61000, 71000, 81000, 91000, 101000, 111000, 121000, 131000, 141000, 151000, 161000, 171000, 181000, 191000, 201000, 211000, 221000, 231000, 241000, 251000, 261000, 271000, 281000, 291000, 301000, 311000, 321000, 331000, 341000, 351000, 361000, 371000, 381000, 391000, 401000])
y = np.array ([3,336,1262,2741,5000,7531,11121,14643,19905,25106,30697,38672,55748,63091,102394,72049,82070,92824,104138,115243,119466,128805,141289,154503,168247,182367,197243,212438,228352,244689,261235,278473,298959,318270,336511,356828,377472,399165,430560,443496,487120])

xnew = np.linspace (x. min (), x. max (), 200 ) 
spl = make_interp_spline (x, y, k = 3)
y_smooth = spl (xnew)

plt.plot (xnew, y_smooth)
plt.show()

plt.axis([0,410000,0,200000])
plt.title('insert sort')
plt.xlabel('size')
plt.ylabel('time, ms')

x = np.array([1000, 11000, 21000, 31000, 41000, 51000, 61000, 71000, 81000, 91000, 101000, 111000, 121000, 131000, 141000, 151000, 161000, 171000, 181000, 191000, 201000, 211000, 221000, 231000, 241000, 251000, 261000, 271000, 281000, 291000, 301000, 311000, 321000, 331000, 341000, 351000, 361000, 371000, 381000, 391000, 401000])
y = np.array ([1,142,522,1128,2026,3082,4472,5927,7990,10166,12483,16076,23589,25699,37349,29743,33826,38182,42992,47688,48061,51928,56894,62260,67817,73468,79426,85886,92096,98836,105947,112898,120408,128317,135896,143829,152361,160862,174059,178951,192884])

xnew = np.linspace (x. min (), x. max (), 200 ) 
spl = make_interp_spline (x, y, k = 3)
y_smooth = spl (xnew)

plt.plot (xnew, y_smooth)
plt.show()

plt.axis([0,410000,0,175000])
plt.title('select sort')
plt.xlabel('size')
plt.ylabel('time, ms')

x = np.array([1000, 11000, 21000, 31000, 41000, 51000, 61000, 71000, 81000, 91000, 101000, 111000, 121000, 131000, 141000, 151000, 161000, 171000, 181000, 191000, 201000, 211000, 221000, 231000, 241000, 251000, 261000, 271000, 281000, 291000, 301000, 311000, 321000, 331000, 341000, 351000, 361000, 371000, 381000, 391000, 401000])
y = np.array ([1,118,432,926,1652,2504,3623,4910,6501,8236,10141,13062,19136,21117,34271,23790,27082,30698,34632,38236,39166,42723,46881,51243,55748,60414,65154,70219,75385,80655,86073,91865,99371,105327,111669,118303,125194,132404,142407,147126,161028])

xnew = np.linspace (x. min (), x. max (), 200 ) 
spl = make_interp_spline (x, y, k = 3)
y_smooth = spl (xnew)

plt.plot (xnew, y_smooth)
plt.show()

plt.axis([0,10000000,0,1300])
plt.title('lsd sort')
plt.xlabel('size')
plt.ylabel('time, ms')

x = np.array([1000, 101000, 201000, 301000, 401000, 501000, 601000, 701000, 801000, 901000, 1001000, 1101000, 1201000, 1301000, 1401000, 1501000, 1601000, 1701000, 1801000, 1901000, 2001000, 2101000, 2201000, 2301000, 2401000, 2501000, 2601000, 2701000, 2801000, 2901000, 3001000, 3101000, 3201000, 3301000, 3401000, 3501000, 3601000, 3701000, 3801000, 3901000, 4001000, 4101000, 4201000, 4301000, 4401000, 4501000, 4601000, 4701000, 4801000, 4901000, 5001000, 5101000, 5201000, 5301000, 5401000, 5501000, 5601000, 5701000, 5801000, 5901000, 6001000, 6101000, 6201000, 6301000, 6401000, 6501000, 6601000, 6701000, 6801000, 6901000, 7001000, 7101000, 7201000, 7301000, 7401000, 7501000, 7601000, 7701000, 7801000, 7901000, 8001000, 8101000, 8201000, 8301000, 8401000, 8501000, 8601000, 8701000, 8801000, 8901000, 9001000, 9101000, 9201000, 9301000, 9401000, 9501000, 9601000, 9701000, 9801000, 9901000])
y = np.array ([0,11,23,34,46,57,69,80,92,104,115,127,140,151,162,174,185,206,233,241,254,266,278,291,304,316,330,344,354,366,381,393,407,420,432,444,457,469,482,495,508,521,531,547,558,572,582,596,609,621,634,647,660,672,684,697,710,722,737,748,763,775,786,798,812,826,838,850,861,876,888,900,915,927,940,952,965,977,990,1002,1016,1029,1043,1055,1074,1086,1100,1111,1124,1138,1149,1161,1175,1193,1202,1215,1226,1240,1290,1261,])

xnew = np.linspace (x. min (), x. max (), 200 ) 
spl = make_interp_spline (x, y, k = 3)
y_smooth = spl (xnew)

plt.plot (xnew, y_smooth)
plt.show()

plt.axis([0,10000000,0,2500])
plt.title('merge sort')
plt.xlabel('size')
plt.ylabel('time, ms')

x = np.array([1000, 101000, 201000, 301000, 401000, 501000, 601000, 701000, 801000, 901000, 1001000, 1101000, 1201000, 1301000, 1401000, 1501000, 1601000, 1701000, 1801000, 1901000, 2001000, 2101000, 2201000, 2301000, 2401000, 2501000, 2601000, 2701000, 2801000, 2901000, 3001000, 3101000, 3201000, 3301000, 3401000, 3501000, 3601000, 3701000, 3801000, 3901000, 4001000, 4101000, 4201000, 4301000, 4401000, 4501000, 4601000, 4701000, 4801000, 4901000, 5001000, 5101000, 5201000, 5301000, 5401000, 5501000, 5601000, 5701000, 5801000, 5901000, 6001000, 6101000, 6201000, 6301000, 6401000, 6501000, 6601000, 6701000, 6801000, 6901000, 7001000, 7101000, 7201000, 7301000, 7401000, 7501000, 7601000, 7701000, 7801000, 7901000, 8001000, 8101000, 8201000, 8301000, 8401000, 8501000, 8601000, 8701000, 8801000, 8901000, 9001000, 9101000, 9201000, 9301000, 9401000, 9501000, 9601000, 9701000, 9801000, 9901000])
y = np.array ([0,17,36,55,74,93,113,135,154,172,194,217,237,258,280,319,351,374,394,417,445,464,494,515,539,567,588,615,636,658,678,703,725,749,769,794,812,835,864,894,920,936,963,991,1018,1048,1067,1080,1113,1144,1167,1194,1211,1239,1267,1295,1312,1336,1351,1378,1407,1423,1455,1474,1498,1524,1549,1578,1593,1619,1651,1674,1699,1714,1736,1764,1780,1813,1839,1870,1891,1916,1955,1975,1989,2022,2050,2083,2106,2129,2151,2177,2199,2230,2230,2261,2353,2408,2426,2446])

xnew = np.linspace (x. min (), x. max (), 200 ) 
spl = make_interp_spline (x, y, k = 3)
y_smooth = spl (xnew)

plt.plot (xnew, y_smooth)
plt.show()
